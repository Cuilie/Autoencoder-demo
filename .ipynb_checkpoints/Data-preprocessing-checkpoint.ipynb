# %%
import scipy.io as sio 
import numpy as np
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt 
import mpl_toolkits
from mpl_toolkits.mplot3d import Axes3D
import re

import imageio,os

mat = sio.loadmat('data/swiss_roll_data.mat')

# %% [markdown]
# ## View the data of swiss roll

# %%
fig =plt.figure()
ax = fig.add_subplot(111,projection = '3d')
ax.scatter(mat['X_data'].T[:,0],mat['X_data'].T[:,1],mat['X_data'].T[:,2],c = mat['Y_data'][0])

# %% [markdown]
# ## Igorne the 3rd dimension

# %%
data_X = np.array([mat['X_data'].T[:,0],mat['X_data'].T[:,1]]).T
data_Y = np.array(mat['Y_data'][0])

fig =plt.figure()
ax = fig.add_subplot(111)
ax.scatter(mat['X_data'].T[:,0],mat['X_data'].T[:,1],c = mat['Y_data'][0], s =1)

# %% [markdown]
# ## Using PCA, reduce to 1 dimension

# %%
pca6 = PCA(n_components = 1)
lower_dimensional_data = pca6.fit_transform(data_X)
n_components6 = len(pca6.explained_variance_ratio_)
approximation6 = pca6.inverse_transform(lower_dimensional_data)
fig =plt.figure()
ax = fig.add_subplot(111)
ax.scatter(approximation6[:,0],approximation6[:,1],c = mat['Y_data'][0],s = 1)

# %%
loss = np.sum((approximation6 - data_X)**2)/data_X.shape[0]
plt.close()
print('PCA loss:', loss)
# Out:
# PCA loss: 50.07133676869117

# %% [markdown]
# ## Trainning an autoencoder for 360 epoch, try to reconstruct the swiss roll

# %%
import os
import torch
import torchvision
from torch import nn
import torch.utils.data as utils
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import MNIST
from torchvision.utils import save_image

# if not os.path.exists('./mlp_img'):
#     os.mkdir('./mlp_img')


def to_img(x):
    x = 0.5 * (x + 1)
    x = x.clamp(0, 1)
    x = x.view(x.size(0), 1, 28, 28)
    return x

pretrain = False
num_epochs = 400
batch_size = 512
learning_rate = 1e-3
minloss = 1e7
img_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])


tensor_x = torch.from_numpy(data_X) # transform to torch tensors
tensor_y =torch.from_numpy(data_Y)

my_dataset = utils.TensorDataset(tensor_x,tensor_y) # create your datset
train_dataloader = utils.DataLoader(my_dataset,batch_size = batch_size,shuffle = True) # create your dataloader
test_dataloader = utils.DataLoader(my_dataset,batch_size = 20000,shuffle = True) # create your dataloader

# %%
class autoencoder(nn.Module):
    
    def __init__(self):
        super(autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(2, 256),
            nn.ReLU(True),
            nn.Linear(256, 64),
            nn.ReLU(True),
            nn.Linear(64, 32), 
            nn.ReLU(True), 
            nn.Linear(32, 8),
            nn.ReLU(True),
            nn.Linear(8, 1))
        self.decoder = nn.Sequential(
            nn.Linear(1, 8),
            nn.ReLU(True),
            nn.Linear(8, 32),
            nn.ReLU(True),
            nn.Linear(32, 64),
            nn.ReLU(True),
            nn.Linear(64, 256),
            nn.ReLU(True), 
            nn.Linear(256, 2))

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x


model = autoencoder()

if pretrain == True:
    model = torch.load('model/model1.pt')

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(
    model.parameters(), lr=learning_rate, weight_decay=1e-5*1.5)

for epoch in range(num_epochs):
    # ===================test&plot========================
    if epoch % 3 == 0:
        for data in test_dataloader:

            testimg, y = data
            testimg = testimg.view(testimg.size(0), -1)
            testimg = Variable(testimg).float()
            testoutput = model(testimg.float())
            testloss = criterion(testoutput, testimg)
            print('Error in all data:epoch [{}/{}], loss:{:.4f}'
              .format(epoch + 1, num_epochs, loss.data.item()))
            
            approximation = testoutput.detach().numpy()
            
            fig = plt.figure(figsize=(9,7))
            plt.scatter(approximation[:,0],approximation[:,1],c = y,s = 1)
            plt.title('After ' + str(epoch) + ' epochs')
            fig.savefig('images/' + str(epoch)+'.png')
            
            plt.close()


            break
    
    for data in train_dataloader:
        
        img, _ = data
        img = img.view(img.size(0), -1)
        img = Variable(img).float()
        # ===================forward=====================
        output = model(img.float())
        loss = criterion(output, img)
        # ===================backward====================
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        
    # ===================log========================
    # print('epoch [{}/{}], loss:{:.4f}'
    #      .format(epoch + 1, num_epochs, loss.data.item()))
    
    # ===================save========================
    if epoch % 10 == 0 and testloss < minloss:
        torch.save(model, 'model'+ str(epoch) + str(testloss)+'.pt')

torch.save(model.state_dict(), './sim_autoencoder.pth')
# Out:
# Error in all data:epoch [1/400], loss:0.5657
# /anaconda3/lib/python3.6/site-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type autoencoder. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Error in all data:epoch [2/400], loss:30.1686
# Error in all data:epoch [3/400], loss:26.2182
# Error in all data:epoch [4/400], loss:19.3675
# Error in all data:epoch [5/400], loss:11.0496
# Error in all data:epoch [6/400], loss:15.9255
# Error in all data:epoch [7/400], loss:3.4785
# Error in all data:epoch [8/400], loss:4.6425
# Error in all data:epoch [9/400], loss:4.9813
# Error in all data:epoch [10/400], loss:4.0166
# Error in all data:epoch [11/400], loss:3.0065
# Error in all data:epoch [12/400], loss:3.3864
# Error in all data:epoch [13/400], loss:2.2855
# Error in all data:epoch [14/400], loss:3.3156
# Error in all data:epoch [15/400], loss:3.0192
# Error in all data:epoch [16/400], loss:3.9991
# Error in all data:epoch [17/400], loss:4.0750
# Error in all data:epoch [18/400], loss:2.9981
# Error in all data:epoch [19/400], loss:3.7522
# Error in all data:epoch [20/400], loss:3.8689
# Error in all data:epoch [21/400], loss:4.5811
# Error in all data:epoch [22/400], loss:3.4037
# Error in all data:epoch [23/400], loss:4.2762
# Error in all data:epoch [24/400], loss:3.0644
# Error in all data:epoch [25/400], loss:3.0997
# Error in all data:epoch [26/400], loss:2.8862
# Error in all data:epoch [27/400], loss:4.1767
# Error in all data:epoch [28/400], loss:2.7091
# Error in all data:epoch [29/400], loss:3.3433
# Error in all data:epoch [30/400], loss:3.6650
# Error in all data:epoch [31/400], loss:3.3435
# Error in all data:epoch [32/400], loss:4.1111
# Error in all data:epoch [33/400], loss:3.3592
# Error in all data:epoch [34/400], loss:3.2660
# Error in all data:epoch [35/400], loss:3.3786
# Error in all data:epoch [36/400], loss:3.2273
# Error in all data:epoch [37/400], loss:3.3090
# Error in all data:epoch [38/400], loss:3.1251
# Error in all data:epoch [39/400], loss:1.4967
# Error in all data:epoch [40/400], loss:2.4578
# Error in all data:epoch [41/400], loss:2.0941
# Error in all data:epoch [42/400], loss:3.4610
# Error in all data:epoch [43/400], loss:3.0606
# Error in all data:epoch [44/400], loss:3.8266
# Error in all data:epoch [45/400], loss:3.3126
# Error in all data:epoch [46/400], loss:1.9752
# Error in all data:epoch [47/400], loss:3.9624
# Error in all data:epoch [48/400], loss:1.8036
# Error in all data:epoch [49/400], loss:2.0449
# Error in all data:epoch [50/400], loss:2.5802
# Error in all data:epoch [51/400], loss:2.8352
# Error in all data:epoch [52/400], loss:1.8703
# Error in all data:epoch [53/400], loss:2.6481
# Error in all data:epoch [54/400], loss:2.5996
# Error in all data:epoch [55/400], loss:2.2710
# Error in all data:epoch [56/400], loss:2.1428
# Error in all data:epoch [57/400], loss:3.1008
# Error in all data:epoch [58/400], loss:1.1171
# Error in all data:epoch [59/400], loss:4.3073
# Error in all data:epoch [60/400], loss:1.4949
# Error in all data:epoch [61/400], loss:1.7135
# Error in all data:epoch [62/400], loss:2.4071
# Error in all data:epoch [63/400], loss:2.4279

# %% [markdown]
# ## Convert all .png image in to a .gif

# %%
os.chdir('images')
images = []
filenames=sorted((fn for fn in os.listdir('.') if fn.endswith('.png')),key=lambda x: int(re.sub('[a-z.]', '', x)))
for filename in filenames:
    images.append(imageio.imread(filename))
imageio.mimsave('gif.gif', images,duration=0.05)
os.chdir(os.path.dirname(os.getcwd()))
